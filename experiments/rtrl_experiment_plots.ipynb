# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ## Humanoid

# %%
df_sac_rt = pd.read_pickle('humanoid/sac_humanoid_real_time_stats')
df_sac_no_rt = pd.read_pickle('humanoid/sac_humanoid_no_real_time_stats')
df_rtac = pd.read_pickle('humanoid/rtac_humanoid_real_time_stats')

# %%
plt.figure(figsize=(8,8))
plt.plot(range(len(df_sac_rt['returns'])), df_sac_rt['returns'], label="SAC RTMDP", color="red")
plt.plot(range(len(df_rtac['returns'])), df_rtac['returns'], label="RTAC RTMDP", color="blue")
plt.plot(range(len(df_sac_no_rt)), df_sac_no_rt['returns'], label="SAC MDP", color="orange")
plt.title("Humanoid-v2", fontweight="bold", fontsize=20)
plt.xlabel("Steps (x1000)", fontsize=14)
plt.ylabel("Return", fontsize=14)
plt.legend()
# plt.savefig("humanoid/humanoid_return.png")

# %%
sac_no_rt_cumsum = df_sac_no_rt['returns'].cumsum()
sac_rt_cumsum = df_sac_rt['returns'].cumsum()
rtac_cumsum = df_rtac['returns'].cumsum()

plt.figure(figsize=(8,8))
plt.plot(range(len(df_sac_rt['returns'])), sac_rt_cumsum, label="SAC RTMDP", color="red")
plt.plot(range(len(df_rtac['returns'])), rtac_cumsum, label="RTAC RTMDP", color="blue")
plt.plot(range(len(df_sac_no_rt)), sac_no_rt_cumsum, label="SAC MDP", color="orange")
plt.title("Humanoid-v2", fontweight="bold", fontsize=20)
plt.xlabel("Steps (x1000)", fontsize=14)
plt.ylabel("Cumulative return", fontsize=14)
plt.legend()
# plt.savefig("humanoid/humanoid_cum_sum.png")

# %% [markdown]
# ## HalfCheetah

# %%
cheetah_sac_rt = pd.read_pickle('cheetah/sac-cheetah-real-time-stats')
cheetah_sac_no_rt = pd.read_pickle('cheetah/sac_cheetah_no_real_time_stats')
cheetah_rtac_rt = pd.read_pickle('cheetah/rtac_cheetah_real_time_stats')

# %%
cheetah_sac_no_rt_cumsum = cheetah_sac_no_rt['returns'].cumsum()
cheetah_sac_rt_cumsum = cheetah_sac_rt['returns'].cumsum()
cheetah_rtac_cumsum = cheetah_rtac_rt['returns'].cumsum()

plt.figure(figsize=(8,8))
plt.plot(range(len(df_sac_rt['returns'])), cheetah_sac_rt_cumsum, label="SAC RTMDP", color="red")
plt.plot(range(len(df_rtac['returns'])), cheetah_rtac_cumsum, label="RTAC RTMDP", color="blue")
plt.plot(range(len(df_sac_no_rt)), cheetah_sac_no_rt_cumsum, label="SAC MDP", color="orange")
plt.title("HalfCheetah-v2", fontweight="bold", fontsize=20)
plt.xlabel("Steps (x1000)", fontsize=14)
plt.ylabel("Cumulative return", fontsize=14)
plt.legend()
# plt.savefig("cheetah/cheetah_cum_sum.png")

# %% [markdown]
# ## Ant

# %%
ant_sac_rt = pd.read_pickle('ant/sac_ant_real_time_stats')
ant_sac_no_rt = pd.read_pickle('ant/sac_ant_no_real_time_stats')
ant_rtac_rt = pd.read_pickle('ant/rtac_ant_real_time_stats')

# %%
ant_sac_no_rt_cumsum = ant_sac_no_rt['returns'].cumsum()
ant_sac_rt_cumsum = ant_sac_rt['returns'].cumsum()
ant_rtac_cumsum = ant_rtac_rt['returns'].cumsum()

plt.figure(figsize=(8,8))
plt.plot(range(len(df_sac_rt['returns'])), ant_sac_rt_cumsum, label="SAC RTMDP", color="red")
plt.plot(range(len(df_rtac['returns'])), ant_rtac_cumsum, label="RTAC RTMDP", color="blue")
plt.plot(range(len(df_sac_no_rt)), ant_sac_no_rt_cumsum, label="SAC MDP", color="orange")
plt.title("Ant-v2", fontweight="bold", fontsize=20)
plt.xlabel("Steps (x1000)", fontsize=14)
plt.ylabel("Cumulative return", fontsize=14)
plt.legend()
# plt.savefig("ant/ant_cum_sum.png")

# %% [markdown]
# ## Pendulum

# %%
pendulum_sac_rt = pd.read_pickle('pendulum/sac_pendulum_real_time_stats')
pendulum_sac_no_rt = pd.read_pickle('pendulum/sac_pendulum_no_real_time_stats')
pendulum_rtac_rt = pd.read_pickle('pendulum/rtac_pendulum_real_time_stats')

# %%
pendulum_sac_no_rt_cumsum = pendulum_sac_no_rt['returns'].cumsum()
pendulum_sac_rt_cumsum = pendulum_sac_rt['returns'].cumsum()
pendulum_rtac_cumsum = pendulum_rtac_rt['returns'].cumsum()

plt.figure(figsize=(8,8))
plt.plot(range(len(df_sac_rt['returns'])), pendulum_sac_rt_cumsum, label="SAC RTMDP", color="red")
plt.plot(range(len(df_rtac['returns'])), pendulum_rtac_cumsum, label="RTAC RTMDP", color="blue")
plt.plot(range(len(df_sac_no_rt)), pendulum_sac_no_rt_cumsum, label="SAC MDP", color="orange")
plt.title("Pendulum", fontweight="bold", fontsize=20)
plt.xlabel("Steps (x1000)", fontsize=14)
plt.ylabel("Cumulative return", fontsize=14)
plt.legend()
# plt.savefig("pendulum/pendulum_cum_sum.png")
